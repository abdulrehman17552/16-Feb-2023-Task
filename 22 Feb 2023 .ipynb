# %%
import pandas as pd

# %%
df = pd.read_csv("london_weekdays.csv")

# %%
# Out:
#       Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0              0  570.098074  Entire home/apt        False         False
# 1              1  297.984430     Private room        False          True
# 2              2  336.790611     Private room        False          True
# 3              3  226.722171     Private room        False          True
# 4              4  256.355982     Private room        False          True
# ...          ...         ...              ...          ...           ...
# 4609        4609  310.449446     Private room        False          True
# 4610        4610  265.057974  Entire home/apt        False         False
# 4611        4611  142.289329     Private room        False          True
# 4612        4612  372.304146     Private room        False          True
# 4613        4613  573.155530  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       realSum  person_capacity        multi          biz  \
# count  4614.000000   4614.000000      4614.000000  4614.000000  4614.000000
# mean   2306.500000    360.230348         2.832466     0.269397     0.422844
# std    1332.091401    507.782888         1.240572     0.443695     0.494065
# min       0.000000     64.676968         2.000000     0.000000     0.000000
# 25%    1153.250000    167.454550         2.000000     0.000000     0.000000
# 50%    2306.500000    256.355982         2.000000     0.000000     0.000000
# 75%    3459.750000    435.452386         4.000000     1.000000     1.000000
# max    4613.000000  15499.894165         6.000000     1.000000     1.000000
#
#        cleanliness_rating  guest_satisfaction_overall     bedrooms  \
# count         4614.000000                 4614.000000  4614.000000
# mean             9.153013                   90.324447     1.123754
# std              1.183012                   11.755838     0.581591
# ...

# %%
len(df)
# Out:
# 4614

# %%
df.describe().loc["mean"]
# Out:
# Unnamed: 0                    2306.500000
# realSum                        360.230348
# person_capacity                  2.832466
# multi                            0.269397
# biz                              0.422844
# cleanliness_rating               9.153013
# guest_satisfaction_overall      90.324447
# bedrooms                         1.123754
# dist                             5.325023
# metro_dist                       0.992739
# attr_index                     296.466825
# attr_index_norm                 20.607738
# rest_index                     629.790258
# rest_index_norm                 11.276920
# lng                             -0.114886
# lat                             51.503262
# Name: mean, dtype: float64

# %%
df.describe().loc[["std","mean"]]["multi"]
# Out:
# std     0.443695
# mean    0.269397
# Name: multi, dtype: float64

# %%
df.describe()

# %%
subset = df[df["room_private"] == True]
subset.head(10)
# Out:
#     Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 1            1  297.984430  Private room        False          True
# 2            2  336.790611  Private room        False          True
# 3            3  226.722171  Private room        False          True
# 4            4  256.355982  Private room        False          True
# 5            5  239.892754  Private room        False          True
# 6            6  324.090407  Private room        False          True
# 7            7  155.695101  Private room        False          True
# 8            8  129.353936  Private room        False          True
# 12          12  207.436675  Private room        False          True
# 13          13  285.049037  Private room        False          True
#
#     person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 1               2.0               True      1    0                10.0  ...
# ...

# %%
df.shape
# Out:
# (4614, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4614 entries, 0 to 4613
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  4614 non-null   int64
#  1   realSum                     4614 non-null   float64
#  2   room_type                   4614 non-null   object
#  3   room_shared                 4614 non-null   bool
#  4   room_private                4614 non-null   bool
#  5   person_capacity             4614 non-null   float64
#  6   host_is_superhost           4614 non-null   bool
#  7   multi                       4614 non-null   int64
#  8   biz                         4614 non-null   int64
#  9   cleanliness_rating          4614 non-null   float64
#  10  guest_satisfaction_overall  4614 non-null   float64
#  11  bedrooms                    4614 non-null   int64
#  12  dist                        4614 non-null   float64
# ...

# %%
subset2 = df[(df["person_capacity"] >= 3) & (df["cleanliness_rating"] == 10.0)]
subset2
# Out:
#       Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 17            17   608.904255  Entire home/apt        False         False
# 25            25  2173.851690  Entire home/apt        False         False
# 26            26   271.878454     Private room        False          True
# 39            39   265.763541  Entire home/apt        False         False
# 40            40   220.372069     Private room        False          True
# ...          ...          ...              ...          ...           ...
# 4574        4574   320.797761     Private room        False          True
# 4594        4594   340.318446  Entire home/apt        False         False
# 4600        4600   258.707872  Entire home/apt        False         False
# 4605        4605   374.891225  Entire home/apt        False         False
# 4613        4613   573.155530  Entire home/apt        False         False
#
#       person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# ...

# %%
#Problem 1
df["Difference"] = df["dist"] - df["metro_dist"]

# %%
df[['Unnamed: 0','dist', 'metro_dist','Difference']].to_csv('Problem1.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0     realSum        room_type  room_shared  room_private  \
# 0           0  570.098074  Entire home/apt        False         False
# 1           1  297.984430     Private room        False          True
# 2           2  336.790611     Private room        False          True
# 3           3  226.722171     Private room        False          True
# 4           4  256.355982     Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    0                10.0  ...
# 1              2.0               True      1    0                10.0  ...
# 2              2.0              False      1    0                10.0  ...
# 3              2.0               True      1    0                10.0  ...
# 4              3.0              False      0    0                 9.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
#Problem 2
df["room_type"].value_counts()
# Out:
# Private room       2625
# Entire home/apt    1966
# Shared room          23
# Name: room_type, dtype: int64

# %%
(df["room_type"].value_counts()).rename("Available Rooms").to_csv('Problem2.csv', index_label='Room Type')

# %%
#Problem 3
df["person_capacity"].value_counts()
# Out:
# 2.0    2891
# 4.0     822
# 3.0     407
# 6.0     308
# 5.0     186
# Name: person_capacity, dtype: int64

# %%
(df["person_capacity"].value_counts()).rename("Available Rooms").to_csv('Problem3.csv', index_label='Person Capacity')

# %%
pd.read_csv("Problem1.csv")
# Out:
#       Unnamed: 0      dist  metro_dist  Difference
# 0              0  5.301018    1.588990    3.712027
# 1              1  2.198946    0.379262    1.819684
# 2              2  2.322958    0.453178    1.869780
# 3              3  5.707825    1.723977    3.983848
# 4              4  3.257945    0.825417    2.432528
# ...          ...       ...         ...         ...
# 4609        4609  6.347654    0.445862    5.901792
# 4610        4610  5.231706    0.463949    4.767757
# 4611        4611  8.867238    2.675007    6.192231
# 4612        4612  7.576798    1.682697    5.894100
# 4613        4613  6.882617    1.432839    5.449778
#
# [4614 rows x 4 columns]
